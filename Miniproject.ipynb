# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi0263/Dsa_solved_questions/blob/main/Miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('Hydra-Movie-Scrape.csv.csv')

# %%
df.head()
# Out:
#                                                Title  Year  \
# 0                        Patton Oswalt: Annihilation  2017
# 1                                      New York Doll  2005
# 2  Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                         Mickey's House of Villains  2001
# 4                                      And Then I Go  2017
#
#                                              Summary  \
# 0  Patton Oswald, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  After everyone is snowed in at the House of Mo...
# 3  The villains from the popular animated Disney ...
# 4  In the cruel world of junior high, Edwin suffe...
#
#                                        Short Summary  \
# 0  Patton Oswalt, despite a personal tragedy, pro...
# 1  A recovering alcoholic and recently converted ...
# 2  Mickey and all his friends hold their own Chri...
# 3  The villains from the popular animated Disney ...
# ...

# %%
df.tail()
# Out:
#                            Title  Year  \
# 3935                  Skyscraper  2018
# 3936                   Trench 11  2017
# 3937        My Daddy's in Heaven  2017
# 3938  Keeping Up with the Steins  2006
# 3939                         UFO  2018
#
#                                                 Summary  \
# 3935  FBI Hostage Rescue Team leader and U.S. war ve...
# 3936  In the final days of WWI, an allied army unit ...
# 3937  Becca, Adam and their 5-year-old daughter Acie...
# 3938  In toney Brentwood, Benjamin Fiedler prepares ...
# 3939  Derek (Alex Sharp) a brilliant college student...
#
#                                           Short Summary  \
# 3935  A security expert must infiltrate a burning sk...
# 3936  In the final days of WWI, an allied army unit ...
# 3937  Becca, Adam and their 5-year-old daughter Acie...
# 3938  A 13-year-old boy uses his upcoming bar mitzva...
# 3939  A college student, who sees a UFO, uses his ex...
#
# ...

# %%
print(df)
# Out:
#                                                   Title  Year  \
# 0                           Patton Oswalt: Annihilation  2017
# 1                                         New York Doll  2005
# 2     Mickey's Magical Christmas: Snowed in at the H...  2001
# 3                            Mickey's House of Villains  2001
# 4                                         And Then I Go  2017
# ...                                                 ...   ...
# 3935                                         Skyscraper  2018
# 3936                                          Trench 11  2017
# 3937                               My Daddy's in Heaven  2017
# 3938                         Keeping Up with the Steins  2006
# 3939                                                UFO  2018
#
#                                                 Summary  \
# 0     Patton Oswald, despite a personal tragedy, pro...
# 1     A recovering alcoholic and recently converted ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3940 entries, 0 to 3939
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            3940 non-null   object
#  1   Year             3940 non-null   int64
#  2   Summary          3935 non-null   object
#  3   Short Summary    3939 non-null   object
#  4   Genres           3940 non-null   object
#  5   IMDB ID          3940 non-null   object
#  6   Runtime          3940 non-null   int64
#  7   YouTube Trailer  3893 non-null   object
#  8   Rating           3940 non-null   float64
#  9   Movie Poster     3940 non-null   object
#  10  Director         3940 non-null   object
#  11  Writers          3922 non-null   object
#  12  Cast             3916 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 400.3+ KB

# %%
 df.columns
# Out:
# Index(['Title', 'Year', 'Summary', 'Short Summary', 'Genres', 'IMDB ID',
#        'Runtime', 'YouTube Trailer', 'Rating', 'Movie Poster', 'Director',
#        'Writers', 'Cast', 'combined_features'],
#       dtype='object')

# %%
features = ['Summary','Cast','Genres','Director']

# %%
def combine_features(row):
    return row['Summary']+" "+row['Cast']+" "+row['Genres']+" "+row['Director']

# %%
if 'Summary' in df.columns:
    print("The 'Summary' column exists.")
else:
    print("The 'Summary' column does not exist.")
# Out:
# The 'Summary' column exists.

# %%
for feature in features:
 df[feature] = df[feature].fillna('')

df["combined_features"] = df.apply(combine_features,axis=1)

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(df["combined_features"])

# %%
cosine_sim = cosine_similarity(count_matrix)

# %%
def get_title_from_year(Year):
    return df[df.Year == Year]["Title"].values[0]
def get_year_from_Title(title):
  if title in df["Title"].values:
        return df[df["Title"] == title]["Year"].values[0]
  else:
        print(f"Movie '{title}' not found in the dataset.")
        return df[df.Year == Year]["Title"].values[0]

movies_user_likes= "New York Doll"
movie_year = get_year_from_Title(movies_user_likes)
if movie_year:
    similar_movies = list(enumerate(cosine_sim[movie_year]))
else:
    print("No similar movies found.")

# %%
"Year" in df.columns
# Out:
# True

# %%
sorted_similar_movies[0]
# Out:
# (2463, 0.4860111144642456)

# %%
sorted_similar_movies = sorted(similar_movies,key=lambda x:x[1],reverse=True)[1:]

# %%
sorted_similar_movies[0]
# Out:
# (2463, 0.4860111144642456)

# %%
i=0
print("Top 5 similar movies to "+movies_user_likes+" are:\n")
for element in sorted_similar_movies:
   if element[0] in df["Year"].values:
    print(get_title_from_year(element[0]))
    i+=1
    if i>5:
        break
# Out:
# Top 5 similar movies to New York Doll are:
#
# The Coming Days
# The Everlasting Flame
# Farewell Ferris Wheel
# The Secret Rules of Modern Living: Algorithms
# The Foster Boy
# Believe in Me
